# %%
from config import g_key
import requests
import gmaps

# %%
#Set the parameters to search for a hotel in Paris 
params = {"radius":5000,"type": "lodging","key": g_key,"location":"48.8566, 2.3522"}

#use base url to search for the hotels in Paris 
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# Make request and get the JSON data from the search.
hotels = requests.get(base_url,params=params).json()
hotels
# Out:
# {'html_attributions': [],
#  'next_page_token': 'Aap_uEAX9AFIvEBR4uvz5tbZEUo8DV0TDZnXy6MGYqH95rOHj__UlCqLbIVFo8HaF3NRSi1jwjFu6sq7GU0Hk8vf6QbiIBY2l_edFy9O02G9Qgb0RPvSIrTfy9aXsdeQ02-yxSKudXYWFzDYfmShOgy0gJwKBdtJhDJTbM1tnRev1Vs2TcQwoRJsyC0weawRg3gdx8a1pZ-2-w0m8pxU2gQJ6MNRE_uCgCazt0MXbzCfKuJce5nfFODGrB17GXeba-NbalYs8bQGJn49jAXVecgo3s2RjaCtIL9AoNlgUEkzdYXNlPnCUM1rHaJEAED5z7mxfqj0qfJRwWm1fNT6oxPATLXdFV4cRZPpXZD1xH44Dalp0aPf1Lj7ClYzymxsvq9LQ_dVWf-KyzZHfthSjC60xmYM-t13HHGLaH5rP6VOPhIy9sT-heEiHWqB',
#  'results': [{'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8581126, 'lng': 2.3529277},
#     'viewport': {'northeast': {'lat': 48.8594360302915,
#       'lng': 2.354355480291502},
#      'southwest': {'lat': 48.8567380697085, 'lng': 2.351657519708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
# ...

# %%
# to get the list of hotels in the results dictionary 
hotels["results"]

#to get hte total number of hotels  in ghe results dict 
len(hotels["results"])
# Out:
# 20

# %%
#To retrieve the name of the first hotel in hte results dict 
hotels["results"][0]["name"]
# Out:
# 'Hôtel Duo'
